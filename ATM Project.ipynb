# %% [markdown]
# ## ATM Project

# %%
class atm:
    def __init__(self,name,accountNO,PIN,balance=0):
        self.name=name
        self.accountNO=accountNO
        self.balance=balance
        self.PIN=PIN

    def details(self):
        ''' display details for person'''
        print(f" Account Holder name is {self.name}")
        print(f" Account number is {self.accountNO}")
        print(f" Current balance is {self.balance}")
    def displayBalance(self):
        print(f"your current balance is {self.balance} ")
    def depositeBalance(self,depo):
        if depo>0:
            self.balance+=depo
            print(f" balance deposite successfully \n now your current blance is : {self.balance} ")
        else: 
            print(" deposite amount must be greater then  0")
    def withdrawBalance(self,amount):
        if self.balance>=amount:
            self.balance-=amount
            print(f" balance withdraw successfully \n your current balance is {self.balance}")
        else:
            print("Insufficient Balance")
    def ChangeName(self,NewName):
        self.name=NewName
        print(f" your Account Holder name change successfully \n your name is {self.name}")
    def showaccountNO(self):
        print(f" your account number is : {self.accountNO}")
    def changepin(self,newpin):
        self.PIN=newpin
        print(" your account PIN change successfully")

    def trans(self):
        print(""" 
        \n1. Account Details
        \n2. Account Balance
        \n3. Deposite Balance
        \n4. Withdraw Balance
        \n5. Change Name
        \n6. ShowAccount Number
        \n7. change PIN
        \n8. Exit""")
        while True:
            try:
                opt=int(input("choose option"))
            except:
                print(" choose correct option")
                continue
            else:
                if opt==1:
                    pin=input("enter your pin")
                    if pin==self.PIN:
                        print(atm.details(self))
                    else:
                        print("enter correct pin")
                       
                elif opt==2:
                    pin=input("enter your pin")
                    if pin==self.PIN:
                        print(f" your current balance is : {self.balance}")
                    else:
                        print("enter correct pin")
                       
                elif opt==3:
                    depo=int(input("enter your ammount"))
                    pin=input("enter your pin")
                    if pin==self.PIN:
                        atm.depositeBalance(self,depo)
                    else:
                        print("enter correct pin")
                       
                elif opt==4:
                    amount=int(input("enter your amount"))
                    pin=input("enter your pin")
                    if pin==self.PIN:
                        atm.withdrawBalance(self,amount)
                    else:
                        print("enter correct pin")
                       
                elif opt==5:
                    NewName=input("enter your new name")
                    pin=input("enter your pin")
                    if pin==self.PIN:
                        atm.ChangeName(self,NewName)
                        
                    else:
                        print("enter correct pin")
                       
                elif opt==6:
                    pin=input("enter your pin")
                    if pin==self.PIN:
                        atm.showaccountNO(self)
                    else:
                        print("enter correct pin")
                elif opt==7:
                    pin = input("Enter your current PIN: ")
                    if pin == self.PIN:
                        newpin = input("Enter new PIN: ")
                        if newpin != self.PIN:
                            self.changePIN(newpin)
                        else:
                            print(" New PIN cannot be same as old PIN.")
                    else:
                        print("Incorrect PIN.")
                elif opt==8:
                    print(" thanks for using ATM")
                    break
obj=atm("kartik","326883892","212725")
obj.trans()
# Out:
#
#
# 1. Account Details
#
# 2. Account Balance
#
# 3. Deposite Balance
#
# 4. Withdraw Balance
#
# 5. Change Name
#
# 6. ShowAccount Number
#
# 7. change PIN
#
# 8. Exit
# choose option 7
# Enter your current PIN:  018114
# Incorrect PIN.
